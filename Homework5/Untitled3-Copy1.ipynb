# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram

# %%
n = 8
n_q = n
n_b = n
qc_output = QuantumCircuit(n_q,n_b)

# %%
for j in range(n):
    qc_output.measure(j,j)

# %%
qc_output.draw()

# %%
counts = execute(qc_output,Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
qc_encode = QuantumCircuit(n)
qc_encode.x(7)

qc_encode.draw()

# %%
qc = qc_encode + qc_output
qc.draw(output='mpl',justify='none')

# %%
counts = execute(qc,Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
qc_encode2 = QuantumCircuit(n)
qc_encode2.x(4)
qc_encode2.x(3)
qc_encode2.x(2)
qc_encode2.x(0)

qc_encode2.draw()

# %%
counts = execute(qc_encode2,Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-11-88cb9bd9a2cd> in <module>
# ----> 1 counts = execute(qc_encode2,Aer.get_backend('qasm_simulator')).result().get_counts()
#       2 plot_histogram(counts)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/qiskit/result/result.py in get_counts(self, experiment)
#     255                 dict_list.append(statevector.Statevector(vec).probabilities_dict(decimals=15))
#     256             else:
# --> 257                 raise QiskitError('No counts for experiment "{0}"'.format(key))
#     258
#     259         # Return first item of dict_list if size is 1
#
# QiskitError: 'No counts for experiment "0"'

# %%
qc_cnot = QuantumCircuit(2)
qc_cnot.cx(0,1)
qc_cnot.draw()

# %%
qc = QuantumCircuit(2,2)
qc.x(0)
qc.cx(0,1)
qc.measure(0,0)
qc.measure(1,1)
qc.draw()
